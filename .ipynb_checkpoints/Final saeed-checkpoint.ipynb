# %%
import cv2

# %%
import matplotlib.pyplot as plt

# %%
img = cv2.imread("C:/Users/PLUS II/OneDrive/Desktop/Hybrid-Image-Generator/Image3.jpg", cv2.IMREAD_GRAYSCALE)

# %%
f,a = plt.subplots(1,1)
a.imshow(img, cmap='gray')
plt.show()

# %%
Image=[]
for i in range(1,5):
    img = cv2.imread(f'image{i}.jpg', cv2.IMREAD_GRAYSCALE) /255
    Image.append(img)

# %%
f,a = plt.subplots(2,2)
a[0,0].imshow(Image[0], cmap='gray')
a[0,1].imshow(Image[1], cmap='gray')
a[1,0].imshow(Image[2], cmap='gray')
a[1,1].imshow(Image[3], cmap='gray')
plt.show()

# %%
Images=[]
for i in range(1,5):
    imgs = cv2.imread(f'images{i}.jpg', cv2.IMREAD_GRAYSCALE)
    Images.append(imgs)

# %%
f,a = plt.subplots(2,2)
a[0,0].imshow(Images[0], cmap='gray')
a[0,1].imshow(Images[1], cmap='gray')
a[1,0].imshow(Images[2], cmap='gray')
a[1,1].imshow(Images[3], cmap='gray')
plt.show()

# %%
width,height=Image[0].shape

# %%
width*height
# Out:
# 1960000

# %%
width
# Out:
# 1400

# %%
height
# Out:
# 1400

# %%
for i in range(4):
    width1,height1=Image[i].shape
    width2,height2=Images[i].shape
    area1=width1*height1
    area2=width2*height2
    print(area1)
    print(area2)
    print(Image[i].shape)
    if area1>area2:
        Image[i]=cv2.resize(Image[i], (height2,width2))
        print(Image[i].shape)
    elif area2>area1:
        Images[i]=cv2.resize(Images[i], (height1,width1))
        print(Image[i].shape)
    else:
        continue
# Out:
# 1960000
# 921600
# (1400, 1400)
# (720, 1280)
# 921600
# 194400
# (720, 1280)
# (360, 540)
# 275200
# 3240000
# (430, 640)
# (430, 640)
# 1440000
# 960000
# (1200, 1200)
# (800, 1200)

# %%
f,a = plt.subplots(2,2)
a[0,0].imshow(Image[0], cmap='gray')
a[0,1].imshow(Image[1], cmap='gray')
a[1,0].imshow(Image[2], cmap='gray')
a[1,1].imshow(Image[3], cmap='gray')
plt.show()

# %%
f,a = plt.subplots(2,2)
a[0,0].imshow(Images[0], cmap='gray')
a[0,1].imshow(Images[1], cmap='gray')
a[1,0].imshow(Images[2], cmap='gray')
a[1,1].imshow(Images[3], cmap='gray')
plt.show()

# %%
for i in range(4):
    Image[i]=cv2.GaussianBlur(Image[i],(85,85),0)
    Images[i]=Images[i]-cv2.GaussianBlur(Images[i],(185,185),0)

# %%
f,a = plt.subplots(2,2)
a[0,0].imshow(Image[0], cmap='gray')
a[0,1].imshow(Image[1], cmap='gray')
a[1,0].imshow(Image[2], cmap='gray')
a[1,1].imshow(Image[3], cmap='gray')
plt.show()

# %%
f,a = plt.subplots(2,2)
a[0,0].imshow(Images[0], cmap='gray')
a[0,1].imshow(Images[1], cmap='gray')
a[1,0].imshow(Images[2], cmap='gray')
a[1,1].imshow(Images[3], cmap='gray')
plt.show()
